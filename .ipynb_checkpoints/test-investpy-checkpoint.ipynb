# %%
import investpy

# %%
etfsUS = investpy.etfs.get_etfs(country='united states');
etfsUS.query('name.str.contains("Vanguard") & name.str.contains("S&P")', engine='python')
# Out:
#             country                               name  \
# 1968  united states                   Vanguard S&P 500
# 2002  united states         Vanguard S&P Small Cap 600
# 2020  united states             Vanguard S&P 500 Value
# 2021  united states            Vanguard S&P 500 Growth
# 2030  united states           Vanguard S&P Mid Cap 400
# 2032  united states     Vanguard S&P Mid Cap 400 Value
# 2033  united states   Vanguard S&P Small Cap 600 Value
# 2036  united states    Vanguard S&P Mid Cap 400 Growth
# 2038  united states  Vanguard S&P Small Cap 600 Growth
#
#                               full_name symbol          isin asset_class  \
# 1968                   Vanguard S&P 500    VOO  US9229083632      equity
# 2002         Vanguard S&P Small Cap 600   VIOO  US9219328286      equity
# 2020             Vanguard S&P 500 Value   VOOV  US9219327031      equity
# 2021            Vanguard S&P 500 Growth   VOOG  US9219325050      equity
# ...

# %%
stock_data = investpy.get_etf_historical_data(etf='Vanguard S&P 500', country='united states', from_date='01/01/2021', to_date='19/04/2021')
stock_data.tail(5)
# Out:
# /Users/SoChigusa/opt/anaconda3/lib/python3.8/site-packages/investpy/etfs.py:587: Warning: Selected country does not contain the default stock exchange of the introduced ETF. Default country is: "hong kong" and default stock_exchange: "Hong Kong".
#   warnings.warn(
#               Open    High     Low   Close   Volume Currency Exchange
# Date
# 2021-04-15  380.35  382.52  380.28  382.29  3573828      USD     NYSE
# 2021-04-16  383.56  384.15  382.19  383.63  3246995      USD     NYSE
# 2021-04-17  383.63  383.63  383.63  383.63        0      USD     NYSE
# 2021-04-18  383.63  383.63  383.63  383.63        0      USD     NYSE
# 2021-04-19  383.63  383.63  380.37  381.74  3945743      USD     NYSE

# %%
stock_data = investpy.get_etf_recent_data(etf='Vanguard S&P 500', country='united states')
stock_data.tail(5)
# Out:
# /Users/SoChigusa/opt/anaconda3/lib/python3.8/site-packages/investpy/etfs.py:286: Warning: Selected country does not contain the default stock exchange of the introduced ETF. Default country is: "hong kong" and default stock_exchange: "Hong Kong".
#   warnings.warn(
#               Open    High     Low   Close   Volume Currency Exchange
# Date
# 2021-04-15  380.35  382.52  380.28  382.29  3573828      USD     NYSE
# 2021-04-16  383.56  384.15  382.19  383.63  3246995      USD     NYSE
# 2021-04-17  383.63  383.63  383.63  383.63        0      USD     NYSE
# 2021-04-18  383.63  383.63  383.63  383.63        0      USD     NYSE
# 2021-04-19  383.63  383.63  380.37  381.74  3945743      USD     NYSE
